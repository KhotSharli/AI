# %%
#Assignment submitted by Ahalya Mandana and Suhail Pallath Sulaiman'
from copy import deepcopy


class Node:
  def __init__(self):
    self.state=[[],[],[]]
    self.nodeNumber=0
    self.status='idle'
    self.neighbours=[]
    self.parent=None
    self.children=[]#For BFS
    self.point=10



def evalFunc(node):
    largest=0
    l=[]
    for peg in initialState:
        if len(peg)>0:
            l.append(max(peg))

    largest=max(l)
    #print 'largest=',largest
    node.point=10
    setPnts(node,largest)

def setPnts(node,largest):
    global finalState
    #print '\n starting setpnts with largest= ',largest,' nodestate=',node.state
    if largest>0:

        for fpeg in finalState:
            if largest in fpeg:

                pos=finalState.index(fpeg)
     #           print largest, 'the largest is on peg no ', pos ,fpeg,' in finalstate. finalstate[pos]='#,finalstate[pos]
                if largest in node.state[pos]:
      #              print largest, 'the largest is on peg no ', pos ,' in node.state. node.state[pos]=',node.state[pos]
       #             print 'reducing point from ', node.point, ' to ', (node.point-1)
                    node.point=node.point-1
        #            print 'starting recursive with largest as ', largest-1
                    setPnts(node,largest-1)



def move(st1,st2):

    s1=st1[:]
    s2=st2[:]

    if len(s1)>0:
        topDisc=s1[len(s1)-1]
        lastofS2=len(s2)-1

        if len(s2)==0 or s2[lastofS2]>topDisc:
            s2.append(topDisc)
            s1.pop()

            return s1,s2
        else:
            return None
    else:
        return None


def moveDisc(n):
    global noOfPegs
    stacks=[]

    for x in range(0,noOfPegs):
        for y in range(0,noOfPegs):

            stacks=move(n.state[x],n.state[y])


            if stacks!=None:
                # print 'states after move', states
                nextnode=Node()
                nextnode=deepcopy(n)
                nextnode.state[x]=deepcopy(stacks[0])
                nextnode.state[y]=deepcopy(stacks[1])


                # print 'states', states
                # print '\n'
                # print 'next node',nextnode.state
                if nextnode.state in states:
                    #print 'nextnode in states'
                    a=1#dumb value
                else:
                    nodenumber=nextnode.nodeNumber
                    # print nextnode.state, 'next not in states'
                    states.append(nextnode.state)
                    return nextnode
    #print 'DEAD END'
    return None

def printPath(node):
    print('Tracing back the Path')
    while True:
        print('Node number:', node.nodeNumber, 'State:', node.state)
        if node.parent != None:
            node = node.parent
        else:
            break



def dfs(node):
    global targetFound, nodenumber
    if not targetFound:
        node.status = 'ongoing'
        parent = deepcopy(node)
        node = moveDisc(node)
        
        if node is not None:
            nodenumber += 1
            node.nodeNumber = nodenumber
            node.parent = parent
            print('Node', node.nodeNumber, node.state, '\n')
            if node.state == finalState:
                print('Final target reached')
                printPath(node)
                targetFound = True
                
            dfs(node)
        else:
            # No valid move, backtrack
            if parent.parent is not None:
                print('Moving back to Node', parent.parent.nodeNumber, 'State', parent.parent.state)
                dfs(parent.parent) 
            
    else:
        return False

def BFS(initial_node):
    parentList = [initial_node]
    childList = []
    nodenumber = initial_node.nodeNumber
    targetFound = False
    step = 1

    while parentList and not targetFound:
        print('\nSTEP:', step)
        step += 1

        for node in parentList:
            if not targetFound:
                print('Parent Node:', node.nodeNumber, 'State:', node.state)
                exhausted = False

                while not exhausted:
                    childnode = moveDisc(node)

                    if childnode is not None:
                        nodenumber += 1
                        childnode.nodeNumber = nodenumber
                        childnode.parent = node
                        node.children.append(childnode)
                        childList.append(childnode)
                        print('  Child Node:', childnode.nodeNumber, 'State:', childnode.state)

                        if childnode.state == finalState:
                            print('Final target reached')
                            printPath(childnode)
                            targetFound = True

                    else:
                        exhausted = True

        parentList = deepcopy(childList)
        childList = []

    if not targetFound:
        print('Target state not reachable.')


def readState():
    global noOfPegs
    state = []
    for x in range(0, noOfPegs):
        print('Discs in Peg', x+1, ':')
        a = [int(x) for x in input().split()]
        state.append(a)
    return state

noOfPegs = 3
shouldContinue = True

while shouldContinue:
    print('\nAssignment submitted by Ahalya Mandana and Suhail Pallath Sulaiman')

    print('\n1. Depth First Search')
    print('2. Breadth First Search')
    print('3 Exit')

    algoNumber = input("Please select the search algorithm --> ")

    if algoNumber == '3':
        print('\nExiting')
        quit()

    print('\nInstructions for input:')
    print('--> An example input for discs in a peg: "3 2 1"')
    print('--> This means your peg has 3 discs with disc of size 3 at the bottom and disc of size 1 at the top')
    print('--> If the peg is empty, just press ENTER without typing anything')

    noOfPegs = int(input("\nEnter number of pegs--> "))

    print('\nEnter details for initial State')
    initialState = readState()
    print('\nEnter details for final State')
    finalState = readState()

    print('\nInitial state:', initialState)
    print('Final states:', finalState)

    states = [initialState]
    nodenumber = 1
    time = 1
    targetFound = False

    node = Node()
    node.state = initialState
    node.nodeNumber = nodenumber
    parentList = [node]
    childList = []
    targetFound = False
    largestInTarget = False
    step = 1

    parentList = [node]
    childList = []

    if algoNumber == '1':
        print('\nYou selected Depth First Search')
        print('Node', node.nodeNumber, node.state, '\n')  # Only for DFS
        dfs(node)

    elif algoNumber == '2':
        print('\nYou selected Breadth First Search')
        BFS(node)

    elif algoNumber == '3':
        print('\nExiting')
        quit()

    else:
        print('Please select a valid option')
        continue



def readState():
    global noOfPegs
    state = []
    for x in range(0, noOfPegs):
        print('Discs in Peg', x+1, ':')
        a = [int(x) for x in input().split()]
        state.append(a)
    return state

noOfPegs = 3
shouldContinue = True

while shouldContinue:
    print('\nAssignment submitted by Ahalya Mandana and Suhail Pallath Sulaiman')

    print('\n1. Depth First Search')
    print('2. Breadth First Search')
    print('3 Exit')

    algoNumber = input("Please select the search algorithm --> ")

    if algoNumber == '3':
        print('\nExiting')
        quit()

    print('\nInstructions for input:')
    print('--> An example input for discs in a peg: "3 2 1"')
    print('--> This means your peg has 3 discs with disc of size 3 at the bottom and disc of size 1 at the top')
    print('--> If the peg is empty, just press ENTER without typing anything')

    noOfPegs = int(input("\nEnter number of pegs--> "))

    print('\nEnter details for initial State')
    initialState = readState()
    print('\nEnter details for final State')
    finalState = readState()

    print('\nInitial state:', initialState)
    print('Final states:', finalState)

    states = [initialState]
    nodenumber = 1
    time = 1
    targetFound = False

    node = Node()
    node.state = initialState
    node.nodeNumber = nodenumber
    parentList = [node]
    childList = []
    targetFound = False
    largestInTarget = False
    step = 1

    parentList = [node]
    childList = []

    if algoNumber == '1':
        print('\nYou selected Depth First Search')
        print('Node', node.nodeNumber, node.state, '\n')  # Only for DFS
        dfs(node)

    elif algoNumber == '2':
        print('\nYou selected Breadth First Search')
        BFS(node)

    elif algoNumber == '3':
        print('\nExiting')
        quit()

    else:
        print('Please select a valid option')
        continue
# Out:
# Assignment submitted by Ahalya Mandana and Suhail Pallath Sulaiman
#
# 1. Depth First Search
# 2. Breadth First Search
# 3 Exit
# Please select the search algorithm --> 2
#
# Instructions for input:
# --> An example input for discs in a peg: "3 2 1"
# --> This means your peg has 3 discs with disc of size 3 at the bottom and disc of size 1 at the top
# --> If the peg is empty, just press ENTER without typing anything
#
# Enter number of pegs--> 3
#
# Enter details for initial State
# Discs in Peg 1 :
# 3
# Discs in Peg 2 :
# 4
# Discs in Peg 3 :
# 5
#
# Enter details for final State
# Discs in Peg 1 :
# 5
# Discs in Peg 2 :
# 6
# Discs in Peg 3 :
# 7
#
# Initial state: [[3], [4], [5]]
# Final states: [[5], [6], [7]]
#
# You selected Breadth First Search
#
# STEP: 1
# Parent Node: 1 State: [[3], [4], [5]]
#   Child Node: 2 State: [[], [4, 3], [5]]
#   Child Node: 3 State: [[], [4], [5, 3]]
#   Child Node: 4 State: [[3], [], [5, 4]]
#
# STEP: 2
# Parent Node: 2 State: [[], [4, 3], [5]]
#   Child Node: 5 State: [[5], [4, 3], []]
# Parent Node: 3 State: [[], [4], [5, 3]]
#   Child Node: 6 State: [[4], [], [5, 3]]
# Parent Node: 4 State: [[3], [], [5, 4]]
#   Child Node: 7 State: [[], [3], [5, 4]]
#   Child Node: 8 State: [[], [], [5, 4, 3]]
#
# STEP: 3
# Parent Node: 5 State: [[5], [4, 3], []]
#   Child Node: 9 State: [[5, 3], [4], []]
#   Child Node: 10 State: [[5], [4], [3]]
# Parent Node: 6 State: [[4], [], [5, 3]]
#   Child Node: 11 State: [[4, 3], [], [5]]
#   Child Node: 12 State: [[4], [3], [5]]
# Parent Node: 7 State: [[], [3], [5, 4]]
# Parent Node: 8 State: [[], [], [5, 4, 3]]
#
# STEP: 4
# Parent Node: 9 State: [[5, 3], [4], []]
#   Child Node: 13 State: [[5, 3], [], [4]]
# Parent Node: 10 State: [[5], [4], [3]]
#   Child Node: 14 State: [[5, 4], [], [3]]
# Parent Node: 11 State: [[4, 3], [], [5]]
#   Child Node: 15 State: [[4, 3], [5], []]
# Parent Node: 12 State: [[4], [3], [5]]
#
# STEP: 5
# Parent Node: 13 State: [[5, 3], [], [4]]
#   Child Node: 16 State: [[5], [3], [4]]
#   Child Node: 17 State: [[5], [], [4, 3]]
# Parent Node: 14 State: [[5, 4], [], [3]]
#   Child Node: 18 State: [[5, 4, 3], [], []]
#   Child Node: 19 State: [[5, 4], [3], []]
# Parent Node: 15 State: [[4, 3], [5], []]
#   Child Node: 20 State: [[4], [5, 3], []]
#   Child Node: 21 State: [[4], [5], [3]]
#
# STEP: 6
# Parent Node: 16 State: [[5], [3], [4]]
# Parent Node: 17 State: [[5], [], [4, 3]]
#   Child Node: 22 State: [[], [5], [4, 3]]
# Parent Node: 18 State: [[5, 4, 3], [], []]
# Parent Node: 19 State: [[5, 4], [3], []]
# Parent Node: 20 State: [[4], [5, 3], []]
#   Child Node: 23 State: [[], [5, 3], [4]]
# Parent Node: 21 State: [[4], [5], [3]]
#   Child Node: 24 State: [[], [5, 4], [3]]
#
# STEP: 7
# Parent Node: 22 State: [[], [5], [4, 3]]
#   Child Node: 25 State: [[3], [5], [4]]
# Parent Node: 23 State: [[], [5, 3], [4]]
# Parent Node: 24 State: [[], [5, 4], [3]]
#   Child Node: 26 State: [[3], [5, 4], []]
#   Child Node: 27 State: [[], [5, 4, 3], []]
#
# STEP: 8
# Parent Node: 25 State: [[3], [5], [4]]
# Parent Node: 26 State: [[3], [5, 4], []]
# Parent Node: 27 State: [[], [5, 4, 3], []]
# Target state not reachable.
#
# Assignment submitted by Ahalya Mandana and Suhail Pallath Sulaiman
#
# 1. Depth First Search
# 2. Breadth First Search
# 3 Exit
# Please select the search algorithm --> 1
#
# Instructions for input:
# --> An example input for discs in a peg: "3 2 1"
# --> This means your peg has 3 discs with disc of size 3 at the bottom and disc of size 1 at the top
# --> If the peg is empty, just press ENTER without typing anything
#
# Enter number of pegs--> 3
#
# Enter details for initial State
# Discs in Peg 1 :
# 3
# Discs in Peg 2 :
# 4
# Discs in Peg 3 :
# 5
#
# Enter details for final State
# Discs in Peg 1 :
# 5
# Discs in Peg 2 :
# 6
# Discs in Peg 3 :
# 7
#
# Initial state: [[3], [4], [5]]
# Final states: [[5], [6], [7]]
#
# You selected Depth First Search
# Node 1 [[3], [4], [5]]
#
# Node 2 [[], [4, 3], [5]]
#
# Node 3 [[], [4], [5, 3]]
#
# Node 4 [[4], [], [5, 3]]
#
# Node 5 [[4, 3], [], [5]]
#
# Node 6 [[4], [3], [5]]
#
# Node 7 [[], [3], [5, 4]]
#
# Node 8 [[3], [], [5, 4]]
#
# Node 9 [[], [], [5, 4, 3]]
#
# Moving back to Node 8 State [[3], [], [5, 4]]
# Moving back to Node 7 State [[], [3], [5, 4]]
# Moving back to Node 6 State [[4], [3], [5]]
# Moving back to Node 5 State [[4, 3], [], [5]]
# Node 10 [[4, 3], [5], []]
#
# Node 11 [[4], [5, 3], []]
#
# Node 12 [[], [5, 3], [4]]
#
# Node 13 [[3], [5], [4]]
#
# Node 14 [[], [5], [4, 3]]
#
# Node 15 [[5], [], [4, 3]]
#
# Node 16 [[5, 3], [], [4]]
#
# Node 17 [[5], [3], [4]]
#
# Node 18 [[5, 4], [3], []]
#
# Node 19 [[5, 4, 3], [], []]
#
# Node 20 [[5, 4], [], [3]]
#
# Node 21 [[5], [4], [3]]
#
# Node 22 [[5, 3], [4], []]
#
# Node 23 [[5], [4, 3], []]
#
# Moving back to Node 22 State [[5, 3], [4], []]
# Moving back to Node 21 State [[5], [4], [3]]
# Moving back to Node 20 State [[5, 4], [], [3]]
# Moving back to Node 19 State [[5, 4, 3], [], []]
# Moving back to Node 18 State [[5, 4], [3], []]
# Moving back to Node 17 State [[5], [3], [4]]
# Moving back to Node 16 State [[5, 3], [], [4]]
# Moving back to Node 15 State [[5], [], [4, 3]]
# Moving back to Node 14 State [[], [5], [4, 3]]
# Moving back to Node 13 State [[3], [5], [4]]
# Node 24 [[3], [5, 4], []]
#
# Node 25 [[], [5, 4, 3], []]
#
# Node 26 [[], [5, 4], [3]]
#
# Node 27 [[4], [5], [3]]
#
# Moving back to Node 26 State [[], [5, 4], [3]]
# Moving back to Node 25 State [[], [5, 4, 3], []]
# Moving back to Node 24 State [[3], [5, 4], []]
# Moving back to Node 13 State [[3], [5], [4]]
# Moving back to Node 12 State [[], [5, 3], [4]]
# Moving back to Node 11 State [[4], [5, 3], []]
# Moving back to Node 10 State [[4, 3], [5], []]
# Moving back to Node 5 State [[4, 3], [], [5]]
# Moving back to Node 4 State [[4], [], [5, 3]]
# Moving back to Node 3 State [[], [4], [5, 3]]
# Moving back to Node 2 State [[], [4, 3], [5]]
# Moving back to Node 1 State [[3], [4], [5]]
#
# Assignment submitted by Ahalya Mandana and Suhail Pallath Sulaiman
#
# 1. Depth First Search
# 2. Breadth First Search
# 3 Exit
# Please select the search algorithm --> 3
#
# Exiting
#
# Instructions for input:
# --> An example input for discs in a peg: "3 2 1"
# --> This means your peg has 3 discs with disc of size 3 at the bottom and disc of size 1 at the top
# --> If the peg is empty, just press ENTER without typing anything
#
# Enter number of pegs--> 1
#
# Enter details for initial State
# Discs in Peg 1 :
# 2
#
# Enter details for final State
# Discs in Peg 1 :
# 4
#
# Initial state: [[2]]
# Final states: [[4]]
#
# Exiting
#
# Assignment submitted by Ahalya Mandana and Suhail Pallath Sulaiman
#
# 1. Depth First Search
# 2. Breadth First Search
# 3 Exit
# Please select the search algorithm --> 4
#
# Instructions for input:
# --> An example input for discs in a peg: "3 2 1"
# --> This means your peg has 3 discs with disc of size 3 at the bottom and disc of size 1 at the top
# --> If the peg is empty, just press ENTER without typing anything
#
# Enter number of pegs--> 1
#
# Enter details for initial State
# Discs in Peg 1 :
# 2
#
# Enter details for final State
# Discs in Peg 1 :
# 23
#
# Initial state: [[2]]
# Final states: [[23]]
# Please select a valid option
#
# Assignment submitted by Ahalya Mandana and Suhail Pallath Sulaiman
#
# 1. Depth First Search
# 2. Breadth First Search
# 3 Exit
# Please select the search algorithm --> 1
#
# Instructions for input:
# --> An example input for discs in a peg: "3 2 1"
# --> This means your peg has 3 discs with disc of size 3 at the bottom and disc of size 1 at the top
# --> If the peg is empty, just press ENTER without typing anything
#
# Enter number of pegs--> 3
#
# Enter details for initial State
# Discs in Peg 1 :
